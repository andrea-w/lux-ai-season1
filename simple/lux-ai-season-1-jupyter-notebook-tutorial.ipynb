# %% [markdown]
# # Lux AI Season 1 Python Tutorial Notebook
#
# Welcome to Lux AI Season 1!
#
# This notebook is the basic setup to use Jupyter Notebooks and the `kaggle-environments` package to develop your bot. If you plan to not use Jupyter Notebooks or any other programming language, please see our [Github](https://github.com/Lux-AI-Challenge/Lux-Design-2021). The following are some important links!
#
# - Competition Page: https://www.kaggle.com/c/lux-ai-2021/
#
# - Online Visualizer: https://2021vis.lux-ai.org/
#
# - Specifications: https://www.lux-ai.org/specs-2021
#
# - Github: https://github.com/Lux-AI-Challenge/Lux-Design-2021
#
# - Bot API: https://github.com/Lux-AI-Challenge/Lux-Design-2021/tree/master/kits
#
# And if you haven't done so already, we **highly recommend** you join our Discord server at https://discord.gg/aWJt3UAcgn or at the minimum follow the kaggle forums at https://www.kaggle.com/c/lux-ai-2021/discussion. We post important announcements there such as changes to rules, events, and opportunities from our sponsors!
#
# Now let's get started!
#
# ## Prerequisites
#
# We assume that you have a basic knowledge of Python and programming. It's okay if you don't know the game specifications yet! Feel free to always refer back to https://www.lux-ai.org/specs-2021.
#
# ## Basic Setup
#
# First thing to verify is that you have **Node.js v12 or above**. The engine for the competition runs on Node.js (for many good reasons including an awesome visualizer) and thus it is required. You can download it [here](https://nodejs.org/en/download/). You can then verify you have the appropriate version by running

# %%
# !node --version
# Out:
# v16.10.0

# %% [markdown]
# We will also need Kaggle Environments

# %%
# !pip install kaggle-environments -U
# Out:
# Requirement already up-to-date: kaggle-environments in /home/andrea/.local/lib/python3.8/site-packages (1.8.12)
# Requirement already satisfied, skipping upgrade: jsonschema>=3.0.1 in /home/andrea/.local/lib/python3.8/site-packages (from kaggle-environments) (3.2.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/lib/python3/dist-packages (from jsonschema>=3.0.1->kaggle-environments) (45.2.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/andrea/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->kaggle-environments) (0.18.0)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /usr/lib/python3/dist-packages (from jsonschema>=3.0.1->kaggle-environments) (1.14.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/andrea/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->kaggle-environments) (21.2.0)

# %% [markdown]
# Next, we have to import the `make` function from the `kaggle_environments` package

# %%
from kaggle_environments import make
from random import randint

# %% [markdown]
# The `make` function is used to create environments that can then run the game given agents. Agents refer to programmed bots that play the game given observations of the game itself.
#
# In addition to making the environment, you may also pass in special configurations such as the number of episode steps (capped at 361) and the seed.
#
# Now lets create our environment using `make` and watch a Episode! (We will be using the seed 562124210 because it's fun)

# %%
# for kaggle-environments
from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES
from lux.constants import Constants
from lux.game_constants import GAME_CONSTANTS
from lux import annotate
from random import randint
import math
import sys

# %%
### Define helper functions

# this snippet finds all resources stored on the map and puts them into a list so we can search over them
def find_resources(game_state):
    resource_tiles: list[Cell] = []
    width, height = game_state.map_width, game_state.map_height
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            if cell.has_resource():
                resource_tiles.append(cell)
    return resource_tiles

# the next snippet finds the closest resources that we can mine given position on a map
def find_closest_resources(pos, player, resource_tiles, unit_positions):
    unit_positions_without_pos = unit_positions
    unit_positions_without_pos.remove(pos)
    for resource_tile in resource_tiles:
        if resource_tile.resource.type == Constants.RESOURCE_TYPES.URANIUM and player.researched_uranium():
            return find_closest_uranium(pos, resource_tiles, unit_positions_without_pos)
        if resource_tile.resource.type == Constants.RESOURCE_TYPES.COAL and player.researched_coal():
            return find_closest_coal(pos, resource_tiles, unit_positions_without_pos)
        return find_closest_wood(pos, resource_tiles, unit_positions_without_pos)

def find_closest_coal(pos, resource_tiles, unit_positions):
    closest_dist = math.inf
    closest_coal_tile = None
    for resource_tile in resource_tiles:
        if resource_tile.resource.type != Constants.RESOURCE_TYPES.COAL:
            continue
        dist = resource_tile.pos.distance_to(pos)
        move_direction = pos.direction_to(resource_tile.pos)
        unit_new_pos = pos.translate(move_direction, 1)
        if dist < closest_dist and resource_tile.pos not in unit_positions and unit_new_pos not in unit_positions:
            closest_dist = dist
            closest_coal_tile = resource_tile
    unit_positions.append(unit_new_pos)
    return (closest_coal_tile, unit_positions)

def find_closest_uranium(pos, resource_tiles, unit_positions):
    closest_dist = math.inf
    closest_uranium_tile = None
    for resource_tile in resource_tiles:
        if resource_tile.resource.type != Constants.RESOURCE_TYPES.URANIUM:
            continue
        dist = resource_tile.pos.distance_to(pos)
        move_direction = pos.direction_to(resource_tile.pos)
        unit_new_pos = pos.translate(move_direction, 1)
        if dist < closest_dist and resource_tile.pos not in unit_positions and unit_new_pos not in unit_positions:
            closest_dist = dist
            closest_uranium_tile = resource_tile
    unit_positions.append(unit_new_pos)
    return (closest_uranium_tile, unit_positions)

def find_closest_wood(pos, resource_tiles, unit_positions):
    closest_dist = math.inf
    closest_wood_tile = None
    for resource_tile in resource_tiles:
        if resource_tile.resource.type != Constants.RESOURCE_TYPES.WOOD:
            continue
        dist = resource_tile.pos.distance_to(pos)
        move_direction = pos.direction_to(resource_tile.pos)
        unit_new_pos = pos.translate(move_direction, 1)
        if dist < closest_dist and resource_tile.pos not in unit_positions and unit_new_pos not in unit_positions:
            closest_dist = dist
            closest_wood_tile = resource_tile
    unit_positions.append(unit_new_pos)
    return (closest_wood_tile, unit_positions)

def find_closest_city_tile(pos, player):
    closest_city_tile = None
    if len(player.cities) > 0:
        closest_dist = math.inf
        # the cities are stored as a dictionary mapping city id to the city object, which has a citytiles field that
        # contains the information of all citytiles in that city
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                dist = city_tile.pos.distance_to(pos)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_city_tile = city_tile
    return closest_city_tile

# returns boolean
def should_build_another_citytile(player):
    total_citytiles = 0
    for city in player.cities.values():
        total_citytiles += len(city.citytiles)
    if len(player.units) == total_citytiles:
        return True
    
    for city in player.cities.values():
        if city.fuel <= city.get_light_upkeep() * 10:
            return False

    return True

def get_city_with_least_fuel(cities):
    lowest_fuel = math.inf
    lowest_fuel_city = None
    for city in cities.values():
        if city.fuel < lowest_fuel:
            lowest_fuel = city.fuel
            lowest_fuel_city = city
    return (lowest_fuel_city, lowest_fuel)

def pick_random_direction():
    meh = randint(0, 4)
    if meh == 0:
        return Constants.DIRECTIONS.CENTER
    elif meh == 1:
        return Constants.DIRECTIONS.EAST
    elif meh == 2:
        return Constants.DIRECTIONS.NORTH
    elif meh == 3:
        return Constants.DIRECTIONS.SOUTH
    elif meh == 4:
        return Constants.DIRECTIONS.WEST

def city_can_build_cart_or_worker(player):
    total_citytiles = 0
    for c in player.cities.values():
        total_citytiles += len(c.citytiles)
    if len(player.units) < total_citytiles:
        return True
    return False

# %%
game_state = None
def agent(observation, configuration):
    global game_state

    ### Do not edit ###
    if observation["step"] == 0:
        game_state = Game()
        game_state._initialize(observation["updates"])
        game_state._update(observation["updates"][2:])
        game_state.id = observation.player
    else:
        game_state._update(observation["updates"])
    
    actions = []

    ### AI Code goes down here! ### 
    player = game_state.players[observation.player]
    opponent = game_state.players[(observation.player + 1) % 2]
    width, height = game_state.map.width, game_state.map.height

    resource_tiles = find_resources(game_state)

    unit_positions = []
    for unit in player.units:
        unit_positions.append(unit.pos)
    
    for unit in player.units:
        # if the unit is a worker (can mine resources) and can perform an action this turn
        if unit.is_worker() and unit.can_act():
            # we want to mine only if there is space left in the worker's cargo
            if unit.get_cargo_space_left() > 0:
                # find the closest resource if it exists to this unit
                closest_resource_tile, unit_positions = find_closest_resources(unit.pos, player, resource_tiles, unit_positions)
                if closest_resource_tile is not None:
                    # create a move action to move this unit in the direction of the closest resource tile and add to our actions list
                    move_direction = unit.pos.direction_to(closest_resource_tile.pos)
                    action = unit.move(move_direction)
                    unit_positions.append(unit.pos.translate(move_direction, 1))
                    actions.append(action)
                else:
                    closest_city_tile = find_closest_city_tile(unit.pos, player)
                    move_direction = unit.pos.direction_to(closest_city_tile.pos)
                    action = unit.move(move_direction)
                    unit_positions.append(unit.pos.translate(move_direction, 1))
                    actions.append(action)
            else:
                lowest_fuel_city, lowest_fuel = get_city_with_least_fuel(player.cities)
                if lowest_fuel <= 230:
                    action = unit.move(unit.pos.direction_to(lowest_fuel_city.citytiles[0].pos))
                    actions.append(action)
                elif unit.pos.distance_to(lowest_fuel_city.citytiles[0].pos) > 0.25 * game_state.map_height:
                    if unit.can_build(game_state.map):
                        actions.append(unit.build_city())
                    else:
                        actions.append(unit.move(pick_random_direction()))
                elif should_build_another_citytile(player):
                    if unit.can_build(game_state.map):
                        actions.append(unit.build_city())
                    else:
                        actions.append(unit.move(pick_random_direction()))
                else:
                    # find the closest citytile and move the unit towards it to drop resources to a citytile to fuel the city
                    closest_city_tile = find_closest_city_tile(unit.pos, player)
                    if closest_city_tile is not None:
                        # create a move action to move this unit in the direction of the closest resource tile and add to our actions list
                        move_direction = unit.pos.direction_to(closest_city_tile.pos)
                        action = unit.move(move_direction)
                        unit_positions.append(unit.pos.translate(move_direction, 1))
                        actions.append(action)
        elif unit.is_cart() and unit.can_act():
            if unit.get_cargo_space_left() > 20:
                closest_resource_tile, unit_positions = find_closest_resources(unit.pos, player, resource_tiles, unit_positions)
                if closest_resource_tile is not None:
                    move_direction = unit.pos.direction_to(closest_resource_tile.pos)
                    action = unit.move(move_direction)
                    unit_positions.append(unit.pos.translate(move_direction, 1))
                    actions.append(action)
            else:
                closest_city_tile = find_closest_city_tile(unit.pos, player)
                if closest_city_tile is not None:
                    move_direction = unit.pos.direction_to(closest_city_tile.pos)
                    actions.append(unit.move(move_direction))
                    unit_positions.append(unit.pos.translate(move_direction, 1))
    
    for city in player.cities.values():
        for city_tile in city.citytiles:
            if city_tile.can_act():
                if city_can_build_cart_or_worker(player):
                    actions.append(city_tile.build_worker())
                else:
                    actions.append(city_tile.research())

    return actions

# %%
env = make("lux_ai_2021", configuration={"seed": 56212210, "loglevel": 2, "annotations": True}, debug=True)
steps = env.run([agent, "simple_agent"])
env.render(mode="ipython", width=1200, height=800)
# Out:
# [WARN] (match_Jr6C0femY7UZ) - turn 49; Unit u_3 collided when trying to move n to (4, 12)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 11) but unit cap reached. Build more CityTiles!; turn 66; cmd: bw 7 11
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (5, 11) but unit cap reached. Build more CityTiles!; turn 88; cmd: bw 5 11
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (8, 12) but unit cap reached. Build more CityTiles!; turn 94; cmd: bw 8 12
# [WARN] (match_Jr6C0femY7UZ) - turn 99; Unit u_3 collided when trying to move n to (6, 11)
# [WARN] (match_Jr6C0femY7UZ) - turn 101; Unit u_3 collided when trying to move c to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 101; Unit u_3 collided when trying to move c to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 101; Unit u_10 collided when trying to move w to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 101; Unit u_12 collided when trying to move e to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 101; Unit u_10 collided when trying to move w to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 101; Unit u_12 collided when trying to move e to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 103; Unit u_3 collided when trying to move n to (6, 11)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (5, 13) but unit cap reached. Build more CityTiles!; turn 105; cmd: bw 5 13
# [WARN] (match_Jr6C0femY7UZ) - turn 110; Unit u_1 collided when trying to move n to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 110; Unit u_13 collided when trying to move w to (6, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 110; Unit u_10 collided when trying to move s to (4, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 110; Unit u_12 collided when trying to move w to (4, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 140; Unit u_11 collided when trying to move w to (7, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 140; Unit u_15 collided when trying to move n to (7, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 141; Unit u_11 collided when trying to move s to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 141; Unit u_15 collided when trying to move e to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 143; Unit u_1 collided when trying to move c to (7, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 143; Unit u_1 collided when trying to move c to (7, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 143; Unit u_15 collided when trying to move n to (7, 12)
# [WARN] (match_Jr6C0femY7UZ) - turn 143; Unit u_15 collided when trying to move n to (7, 12)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (9, 14) but unit cap reached. Build more CityTiles!; turn 144; cmd: bw 9 14
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (3, 13) but unit cap reached. Build more CityTiles!; turn 160; cmd: bw 3 13
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (5, 14) but unit cap reached. Build more CityTiles!; turn 164; cmd: bw 5 14
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (8, 16) but unit cap reached. Build more CityTiles!; turn 164; cmd: bw 8 16
# [WARN] (match_Jr6C0femY7UZ) - turn 164; Unit u_1 collided when trying to move s to (8, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 164; Unit u_12 collided when trying to move e to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 164; Unit u_5 collided when trying to move c to (8, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 164; Unit u_1 collided when trying to move s to (8, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 164; Unit u_5 collided when trying to move c to (8, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 168; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 168; Unit u_23 collided when trying to move e to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 169; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 169; Unit u_25 collided when trying to move s to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 13) but unit cap reached. Build more CityTiles!; turn 170; cmd: bw 7 13
# [WARN] (match_Jr6C0femY7UZ) - turn 170; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 170; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 171; Unit u_3 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 171; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 171; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 172; Unit u_3 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 172; Unit u_18 collided when trying to move c to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 172; Unit u_3 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 172; Unit u_18 collided when trying to move c to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 172; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 172; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 173; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 173; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 174; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 174; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 175; Unit u_10 collided when trying to move n to (9, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 175; Unit u_30 collided when trying to move s to (9, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 175; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 175; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 176; Unit u_10 collided when trying to move n to (9, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 176; Unit u_30 collided when trying to move s to (9, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 176; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 176; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 177; Unit u_10 collided when trying to move n to (9, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 177; Unit u_30 collided when trying to move s to (9, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 177; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 177; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 178; Unit u_3 collided when trying to move c to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 178; Unit u_3 collided when trying to move c to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 178; Unit u_18 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 178; Unit u_18 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 178; Unit u_12 collided when trying to move n to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 178; Unit u_13 collided when trying to move w to (8, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 184; Unit u_3 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 184; Unit u_18 collided when trying to move c to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 184; Unit u_3 collided when trying to move n to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 184; Unit u_18 collided when trying to move c to (4, 13)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (9, 13) but unit cap reached. Build more CityTiles!; turn 190; cmd: bw 9 13
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (8, 15) but unit cap reached. Build more CityTiles!; turn 190; cmd: bw 8 15
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (9, 17) but unit cap reached. Build more CityTiles!; turn 190; cmd: bw 9 17
# [WARN] (match_Jr6C0femY7UZ) - turn 201; Unit u_23 collided when trying to move n to (7, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 201; Unit u_33 collided when trying to move n to (6, 17)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 15) but unit cap reached. Build more CityTiles!; turn 203; cmd: bw 7 15
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (16, 13) but unit cap reached. Build more CityTiles!; turn 203; cmd: bw 16 13
# [WARN] (match_Jr6C0femY7UZ) - turn 204; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 204; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (6, 16) but unit cap reached. Build more CityTiles!; turn 205; cmd: bw 6 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (6, 17) but unit cap reached. Build more CityTiles!; turn 205; cmd: bw 6 17
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 17) but unit cap reached. Build more CityTiles!; turn 205; cmd: bw 7 17
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (4, 15) but unit cap reached. Build more CityTiles!; turn 205; cmd: bw 4 15
# [WARN] (match_Jr6C0femY7UZ) - turn 205; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 205; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 206; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 206; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 207; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 207; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 208; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 208; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 209; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 209; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 210; Unit u_5 collided when trying to move w to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 210; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 210; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 210; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 211; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 211; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 211; Unit u_33 collided when trying to move w to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 211; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 212; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 212; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 212; Unit u_33 collided when trying to move w to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 212; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 213; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 213; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 213; Unit u_33 collided when trying to move w to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 213; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 214; Unit u_29 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 214; Unit u_32 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 214; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 214; Unit u_57 collided when trying to move s to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 215; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 215; Unit u_57 collided when trying to move s to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 216; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 216; Unit u_57 collided when trying to move s to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 217; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 217; Unit u_57 collided when trying to move s to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 217; Unit u_66 collided when trying to move n to (8, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 217; Unit u_1 collided when trying to move n to (8, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 218; Unit u_36 collided when trying to move n to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 218; Unit u_57 collided when trying to move s to (5, 17)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (5, 18) but unit cap reached. Build more CityTiles!; turn 220; cmd: bw 5 18
# [WARN] (match_Jr6C0femY7UZ) - turn 220; Unit u_1 collided when trying to move w to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 220; Unit u_56 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 220; Unit u_17 collided when trying to move s to (15, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 220; Unit u_67 collided when trying to move e to (15, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 220; Unit u_36 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 220; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 221; Unit u_1 collided when trying to move w to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 221; Unit u_56 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 221; Unit u_17 collided when trying to move s to (15, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 221; Unit u_67 collided when trying to move e to (15, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 221; Unit u_36 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 221; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 222; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 222; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (10, 18) but unit cap reached. Build more CityTiles!; turn 223; cmd: bw 10 18
# [WARN] (match_Jr6C0femY7UZ) - turn 223; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 223; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 223; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 223; Unit u_58 collided when trying to move e to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 223; Unit u_65 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_71 collided when trying to move e to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_58 collided when trying to move e to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_59 collided when trying to move e to (16, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_72 collided when trying to move n to (15, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 224; Unit u_65 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_54 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_58 collided when trying to move e to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_59 collided when trying to move e to (16, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 225; Unit u_65 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_18 collided when trying to move s to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_57 collided when trying to move n to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_54 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_58 collided when trying to move s to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 226; Unit u_67 collided when trying to move n to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_18 collided when trying to move s to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_57 collided when trying to move n to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_54 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_58 collided when trying to move s to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_67 collided when trying to move n to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 227; Unit u_72 collided when trying to move e to (16, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_18 collided when trying to move s to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_57 collided when trying to move n to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_54 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_58 collided when trying to move s to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_67 collided when trying to move n to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_72 collided when trying to move e to (16, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 228; Unit u_65 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_18 collided when trying to move s to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_57 collided when trying to move n to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_54 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_56 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_71 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_1 collided when trying to move n to (7, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_58 collided when trying to move s to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_67 collided when trying to move n to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_72 collided when trying to move e to (16, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 229; Unit u_65 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_18 collided when trying to move s to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_57 collided when trying to move n to (4, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_23 collided when trying to move w to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_2 collided when trying to move e to (4, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_29 collided when trying to move n to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_54 collided when trying to move s to (9, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_56 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_71 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_1 collided when trying to move n to (7, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_58 collided when trying to move s to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_67 collided when trying to move n to (16, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_72 collided when trying to move e to (16, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 230; Unit u_65 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 16) but unit cap reached. Build more CityTiles!; turn 235; cmd: bw 7 16
# [WARN] (match_Jr6C0femY7UZ) - turn 235; Unit u_18 collided when trying to move s to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 235; Unit u_2 collided when trying to move e to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (6, 16) but unit cap reached. Build more CityTiles!; turn 236; cmd: bw 6 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (6, 17) but unit cap reached. Build more CityTiles!; turn 236; cmd: bw 6 17
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 17) but unit cap reached. Build more CityTiles!; turn 236; cmd: bw 7 17
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (4, 15) but unit cap reached. Build more CityTiles!; turn 236; cmd: bw 4 15
# [WARN] (match_Jr6C0femY7UZ) - turn 236; Unit u_18 collided when trying to move s to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 236; Unit u_2 collided when trying to move e to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (7, 17) but unit cap reached. Build more CityTiles!; turn 237; cmd: bw 7 17
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (4, 15) but unit cap reached. Build more CityTiles!; turn 237; cmd: bw 4 15
# [WARN] (match_Jr6C0femY7UZ) - turn 237; Unit u_18 collided when trying to move s to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 237; Unit u_2 collided when trying to move e to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 241; Unit u_5 collided when trying to move n to (6, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 241; Unit u_1 collided when trying to move n to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 243; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 243; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 243; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 243; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 243; Unit u_71 collided when trying to move n to (8, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 244; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 244; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 244; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 244; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 244; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 245; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 245; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 245; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 245; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 245; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_5 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_79 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 246; Unit u_71 collided when trying to move n to (8, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_5 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_79 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 247; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_5 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_79 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 248; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 249; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 249; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 249; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 249; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 249; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 249; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 250; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 250; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 250; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 250; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 250; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 250; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 251; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 251; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 251; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 251; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 251; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 251; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_79 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 252; Unit u_97 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_79 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 253; Unit u_97 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_79 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 254; Unit u_97 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_97 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 255; Unit u_103 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 256; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 256; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 256; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 256; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 256; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 256; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_23 collided when trying to move n to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_102 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 257; Unit u_61 collided when trying to move n to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_102 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 258; Unit u_94 collided when trying to move n to (17, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_102 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 259; Unit u_94 collided when trying to move n to (17, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_1 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_102 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_94 collided when trying to move n to (17, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 260; Unit u_61 collided when trying to move n to (6, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_1 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_106 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_61 collided when trying to move n to (6, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_102 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 261; Unit u_94 collided when trying to move n to (17, 16)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_1 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_97 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_17 collided when trying to move n to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_65 collided when trying to move w to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_64 collided when trying to move n to (19, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_59 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_102 collided when trying to move s to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_60 collided when trying to move n to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 262; Unit u_94 collided when trying to move n to (17, 16)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (17, 16) but unit cap reached. Build more CityTiles!; turn 264; cmd: bw 17 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 16) but unit cap reached. Build more CityTiles!; turn 264; cmd: bw 19 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 15) but unit cap reached. Build more CityTiles!; turn 264; cmd: bw 19 15
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (12, 25) but unit cap reached. Build more CityTiles!; turn 264; cmd: bw 12 25
# [WARN] (match_Jr6C0femY7UZ) - turn 264; Unit u_1 collided when trying to move w to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 264; Unit u_29 collided when trying to move n to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 264; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 264; Unit u_101 collided when trying to move e to (8, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 264; Unit u_103 collided when trying to move n to (8, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 265; Unit u_1 collided when trying to move w to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 265; Unit u_29 collided when trying to move n to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 265; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 265; Unit u_101 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 266; Unit u_1 collided when trying to move w to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 266; Unit u_29 collided when trying to move n to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 266; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 266; Unit u_97 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 267; Unit u_1 collided when trying to move w to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 267; Unit u_29 collided when trying to move n to (6, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 267; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 267; Unit u_97 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 268; Unit u_29 collided when trying to move e to (7, 20)
# [WARN] (match_Jr6C0femY7UZ) - turn 268; Unit u_111 collided when trying to move s to (7, 20)
# [WARN] (match_Jr6C0femY7UZ) - turn 268; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 268; Unit u_97 collided when trying to move s to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 269; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 269; Unit u_111 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 269; Unit u_105 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 270; Unit u_61 collided when trying to move e to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 270; Unit u_111 collided when trying to move n to (7, 18)
# [WARN] (match_Jr6C0femY7UZ) - turn 282; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 282; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 283; Unit u_17 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 283; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 283; Unit u_100 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 283; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 283; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 284; Unit u_17 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 284; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 284; Unit u_100 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 284; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 284; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 285; Unit u_17 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 285; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 285; Unit u_100 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 285; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 285; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 286; Unit u_17 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 286; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 286; Unit u_100 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 286; Unit u_60 collided when trying to move n to (19, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 286; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 286; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 287; Unit u_17 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 287; Unit u_62 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 287; Unit u_100 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 287; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 287; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 288; Unit u_62 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 288; Unit u_17 collided when trying to move n to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 288; Unit u_132 collided when trying to move w to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 289; Unit u_29 collided when trying to move n to (7, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 289; Unit u_137 collided when trying to move w to (7, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 289; Unit u_62 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 289; Unit u_17 collided when trying to move n to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 289; Unit u_110 collided when trying to move s to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 289; Unit u_132 collided when trying to move w to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 290; Unit u_62 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 290; Unit u_17 collided when trying to move n to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 290; Unit u_110 collided when trying to move s to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 290; Unit u_132 collided when trying to move w to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 291; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 291; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 292; Unit u_130 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 292; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 293; Unit u_112 collided when trying to move w to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 293; Unit u_132 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 295; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 295; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 295; Unit u_135 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 295; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 296; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 296; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 296; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 296; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 296; Unit u_135 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 297; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 297; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 297; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 297; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 297; Unit u_135 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 298; Unit u_17 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 298; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 298; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 298; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 298; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 299; Unit u_17 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 299; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 299; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 299; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 299; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 300; Unit u_17 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 300; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 300; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 300; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 300; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 301; Unit u_17 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 301; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 301; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 301; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 301; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 302; Unit u_17 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 302; Unit u_100 collided when trying to move n to (17, 13)
# ...
# [WARN] (match_Jr6C0femY7UZ) - turn 309; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 309; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 309; Unit u_130 collided when trying to move w to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 309; Unit u_135 collided when trying to move s to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_17 collided when trying to move e to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_100 collided when trying to move n to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_62 collided when trying to move n to (17, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_132 collided when trying to move w to (17, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_110 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_130 collided when trying to move w to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - turn 310; Unit u_135 collided when trying to move s to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (17, 16) but unit cap reached. Build more CityTiles!; turn 315; cmd: bw 17 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 16) but unit cap reached. Build more CityTiles!; turn 315; cmd: bw 19 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 15) but unit cap reached. Build more CityTiles!; turn 315; cmd: bw 19 15
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (17, 16) but unit cap reached. Build more CityTiles!; turn 316; cmd: bw 17 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 16) but unit cap reached. Build more CityTiles!; turn 316; cmd: bw 19 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 15) but unit cap reached. Build more CityTiles!; turn 316; cmd: bw 19 15
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (17, 16) but unit cap reached. Build more CityTiles!; turn 317; cmd: bw 17 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 16) but unit cap reached. Build more CityTiles!; turn 317; cmd: bw 19 16
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 15) but unit cap reached. Build more CityTiles!; turn 317; cmd: bw 19 15
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (19, 15) but unit cap reached. Build more CityTiles!; turn 318; cmd: bw 19 15
# [WARN] (match_Jr6C0femY7UZ) - turn 321; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 321; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 322; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 322; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 323; Unit u_17 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 323; Unit u_100 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 323; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 323; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 323; Unit u_144 collided when trying to move n to (4, 17)
# [WARN] (match_Jr6C0femY7UZ) - turn 324; Unit u_17 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 324; Unit u_100 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 324; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 324; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 325; Unit u_17 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 325; Unit u_100 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 325; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 325; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 325; Unit u_130 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 325; Unit u_159 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 326; Unit u_17 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 326; Unit u_100 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 326; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 326; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 326; Unit u_130 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 326; Unit u_159 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 327; Unit u_17 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 327; Unit u_100 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 327; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 327; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 327; Unit u_130 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 327; Unit u_159 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 328; Unit u_17 collided when trying to move s to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 328; Unit u_100 collided when trying to move w to (17, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 328; Unit u_110 collided when trying to move s to (18, 15)
# [WARN] (match_Jr6C0femY7UZ) - turn 328; Unit u_132 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 328; Unit u_130 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 328; Unit u_159 collided when trying to move n to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (18, 12) but unit cap reached. Build more CityTiles!; turn 330; cmd: bw 18 12
# [WARN] (match_Jr6C0femY7UZ) - turn 335; Unit u_161 collided when trying to move n to (18, 13)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (6, 19) but unit cap reached. Build more CityTiles!; turn 336; cmd: bw 6 19
# [WARN] (match_Jr6C0femY7UZ) - turn 340; Unit u_162 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 343; Unit u_94 collided when trying to move w to (18, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 345; Unit u_63 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 345; Unit u_110 collided when trying to move w to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 345; Unit u_130 collided when trying to move w to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 346; Unit u_63 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 346; Unit u_110 collided when trying to move w to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 346; Unit u_130 collided when trying to move w to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 347; Unit u_63 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 347; Unit u_110 collided when trying to move w to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 347; Unit u_112 collided when trying to move s to (19, 14)
# [WARN] (match_Jr6C0femY7UZ) - Agent 0 tried to build unit on tile (16, 19) but unit cap reached. Build more CityTiles!; turn 349; cmd: bw 16 19
# [WARN] (match_Jr6C0femY7UZ) - turn 349; Unit u_60 collided when trying to move e to (15, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 349; Unit u_59 collided when trying to move e to (14, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 349; Unit u_161 collided when trying to move w to (15, 19)
# [WARN] (match_Jr6C0femY7UZ) - turn 349; Unit u_63 collided when trying to move s to (18, 14)
# [WARN] (match_Jr6C0femY7UZ) - turn 350; Unit u_17 collided when trying to move e to (17, 18)
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;89b86966-2666-11ec-9940-f98e4f25fd55&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 56212210,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;number&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 32,
#             &quot;height&quot;: 32,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;32 32&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 0 373&quot;,
#               &quot;r wood 0 31 373&quot;,
#               &quot;r coal 1 6 399&quot;,
#               &quot;r coal 1 25 399&quot;,
#               &quot;r coal 2 5 415&quot;,
#               &quot;r coal 2 6 378&quot;,
#               &quot;r coal 2 25 378&quot;,
#               &quot;r coal 2 26 415&quot;,
#               &quot;r wood 4 12 800&quot;,
#               &quot;r wood 4 13 800&quot;,
#               &quot;r wood 4 14 800&quot;,
#               &quot;r wood 4 17 800&quot;,
#               &quot;r wood 4 18 800&quot;,
#               &quot;r wood 4 19 800&quot;,
#               &quot;r wood 5 12 375&quot;,
#               &quot;r wood 5 19 375&quot;,
#               &quot;r wood 6 11 373&quot;,
#               &quot;r wood 6 12 372&quot;,
#               &quot;r wood 6 13 354&quot;,
#               &quot;r wood 6 18 354&quot;,
#               &quot;r wood 6 19 372&quot;,
#               &quot;r wood 6 20 373&quot;,
#               &quot;r wood 7 12 387&quot;,
#               &quot;r wood 7 13 384&quot;,
#               &quot;r wood 7 18 384&quot;,
#               &quot;r wood 7 19 387&quot;,
#               &quot;r wood 8 13 301&quot;,
#               &quot;r wood 8 14 312&quot;,
#               &quot;r wood 8 17 312&quot;,
#               &q

# %% [markdown]
# Ok so woah, what just happened? We just ran a match, that's what :)
#
# There's a number of quality of life features in the visualizer, which you can also find embedded on the kaggle competition page when watching replays or on the online visualizer when using replay files.
#
# If you find this replay viewer slow, you can also download a local copy of this replay viewer in addition to lowering the graphics quality, see https://github.com/Lux-AI-Challenge/LuxViewer2021 for instructions.
#
# At this point, we recommend reading the [game specifications](https://www.lux-ai.org/specs-2021) a bit more to understand how to build a bot that tries to win the game.

# %%
# %%writefile agent.py
# for kaggle-environments
from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES
from lux.constants import Constants
from lux.game_constants import GAME_CONSTANTS
from lux import annotate
from random import randint
import math
import sys

### Define helper functions

# this snippet finds all resources stored on the map and puts them into a list so we can search over them
def find_resources(game_state):
    resource_tiles: list[Cell] = []
    width, height = game_state.map_width, game_state.map_height
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            if cell.has_resource():
                resource_tiles.append(cell)
    return resource_tiles

# the next snippet finds the closest resources that we can mine given position on a map
def find_closest_resources(pos, player, resource_tiles, unit_positions):
    unit_positions_without_pos = unit_positions
    unit_positions_without_pos.remove(pos)
    for resource_tile in resource_tiles:
        if resource_tile.resource.type == Constants.RESOURCE_TYPES.URANIUM and player.researched_uranium():
            return find_closest_uranium(pos, resource_tiles, unit_positions_without_pos)
        if resource_tile.resource.type == Constants.RESOURCE_TYPES.COAL and player.researched_coal():
            return find_closest_coal(pos, resource_tiles, unit_positions_without_pos)
        return find_closest_wood(pos, resource_tiles, unit_positions_without_pos)

def find_closest_coal(pos, resource_tiles, unit_positions):
    closest_dist = math.inf
    closest_coal_tile = None
    for resource_tile in resource_tiles:
        if resource_tile.resource.type != Constants.RESOURCE_TYPES.COAL:
            continue
        dist = resource_tile.pos.distance_to(pos)
        move_direction = pos.direction_to(resource_tile.pos)
        unit_new_pos = pos.translate(move_direction, 1)
        if dist < closest_dist and resource_tile.pos not in unit_positions and unit_new_pos not in unit_positions:
            closest_dist = dist
            closest_coal_tile = resource_tile
    unit_positions.append(unit_new_pos)
    return (closest_coal_tile, unit_positions)

def find_closest_uranium(pos, resource_tiles, unit_positions):
    closest_dist = math.inf
    closest_uranium_tile = None
    for resource_tile in resource_tiles:
        if resource_tile.resource.type != Constants.RESOURCE_TYPES.URANIUM:
            continue
        dist = resource_tile.pos.distance_to(pos)
        move_direction = pos.direction_to(resource_tile.pos)
        unit_new_pos = pos.translate(move_direction, 1)
        if dist < closest_dist and resource_tile.pos not in unit_positions and unit_new_pos not in unit_positions:
            closest_dist = dist
            closest_uranium_tile = resource_tile
    unit_positions.append(unit_new_pos)
    return (closest_uranium_tile, unit_positions)

def find_closest_wood(pos, resource_tiles, unit_positions):
    closest_dist = math.inf
    closest_wood_tile = None
    for resource_tile in resource_tiles:
        if resource_tile.resource.type != Constants.RESOURCE_TYPES.WOOD:
            continue
        dist = resource_tile.pos.distance_to(pos)
        move_direction = pos.direction_to(resource_tile.pos)
        unit_new_pos = pos.translate(move_direction, 1)
        if dist < closest_dist and resource_tile.pos not in unit_positions and unit_new_pos not in unit_positions:
            closest_dist = dist
            closest_wood_tile = resource_tile
    unit_positions.append(unit_new_pos)
    return (closest_wood_tile, unit_positions)

def find_closest_city_tile(pos, player):
    closest_city_tile = None
    if len(player.cities) > 0:
        closest_dist = math.inf
        # the cities are stored as a dictionary mapping city id to the city object, which has a citytiles field that
        # contains the information of all citytiles in that city
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                dist = city_tile.pos.distance_to(pos)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_city_tile = city_tile
    return closest_city_tile

# returns boolean
def should_build_another_citytile(player):
    total_citytiles = 0
    for city in player.cities.values():
        total_citytiles += len(city.citytiles)
    if len(player.units) == total_citytiles:
        return True
    
    for city in player.cities.values():
        if city.fuel <= city.get_light_upkeep() * 10:
            return False

    return True

def get_city_with_least_fuel(cities):
    lowest_fuel = math.inf
    lowest_fuel_city = None
    for city in cities.values():
        if city.fuel < lowest_fuel:
            lowest_fuel = city.fuel
            lowest_fuel_city = city
    return (lowest_fuel_city, lowest_fuel)

def pick_random_direction():
    meh = randint(0, 4)
    if meh == 0:
        return Constants.DIRECTIONS.CENTER
    elif meh == 1:
        return Constants.DIRECTIONS.EAST
    elif meh == 2:
        return Constants.DIRECTIONS.NORTH
    elif meh == 3:
        return Constants.DIRECTIONS.SOUTH
    elif meh == 4:
        return Constants.DIRECTIONS.WEST

def city_can_build_cart_or_worker(player):
    total_citytiles = 0
    for c in player.cities.values():
        total_citytiles += len(c.citytiles)
    if len(player.units) < total_citytiles:
        return True
    return False

game_state = None
def agent(observation, configuration):
    global game_state

    ### Do not edit ###
    if observation["step"] == 0:
        game_state = Game()
        game_state._initialize(observation["updates"])
        game_state._update(observation["updates"][2:])
        game_state.id = observation.player
    else:
        game_state._update(observation["updates"])
    
    actions = []

    ### AI Code goes down here! ### 
    player = game_state.players[observation.player]
    opponent = game_state.players[(observation.player + 1) % 2]
    width, height = game_state.map.width, game_state.map.height

    resource_tiles = find_resources(game_state)

    unit_positions = []
    for unit in player.units:
        unit_positions.append(unit.pos)
    
    for unit in player.units:
        # if the unit is a worker (can mine resources) and can perform an action this turn
        if unit.is_worker() and unit.can_act():
            # we want to mine only if there is space left in the worker's cargo
            if unit.get_cargo_space_left() > 0:
                # find the closest resource if it exists to this unit
                closest_resource_tile, unit_positions = find_closest_resources(unit.pos, player, resource_tiles, unit_positions)
                if closest_resource_tile is not None:
                    # create a move action to move this unit in the direction of the closest resource tile and add to our actions list
                    move_direction = unit.pos.direction_to(closest_resource_tile.pos)
                    action = unit.move(move_direction)
                    unit_positions.append(unit.pos.translate(move_direction, 1))
                    actions.append(action)
                else:
                    closest_city_tile = find_closest_city_tile(unit.pos, player)
                    move_direction = unit.pos.direction_to(closest_city_tile.pos)
                    action = unit.move(move_direction)
                    unit_positions.append(unit.pos.translate(move_direction, 1))
                    actions.append(action)
            else:
                lowest_fuel_city, lowest_fuel = get_city_with_least_fuel(player.cities)
                if lowest_fuel <= 230:
                    action = unit.move(unit.pos.direction_to(lowest_fuel_city.citytiles[0].pos))
                    actions.append(action)
                elif unit.pos.distance_to(lowest_fuel_city.citytiles[0].pos) > 0.25 * game_state.map_height:
                    if unit.can_build(game_state.map):
                        actions.append(unit.build_city())
                    else:
                        actions.append(unit.move(pick_random_direction()))
                elif should_build_another_citytile(player):
                    if unit.can_build(game_state.map):
                        actions.append(unit.build_city())
                    else:
                        actions.append(unit.move(pick_random_direction()))
                else:
                    # find the closest citytile and move the unit towards it to drop resources to a citytile to fuel the city
                    closest_city_tile = find_closest_city_tile(unit.pos, player)
                    if closest_city_tile is not None:
                        # create a move action to move this unit in the direction of the closest resource tile and add to our actions list
                        move_direction = unit.pos.direction_to(closest_city_tile.pos)
                        action = unit.move(move_direction)
                        unit_positions.append(unit.pos.translate(move_direction, 1))
                        actions.append(action)
        elif unit.is_cart() and unit.can_act():
            if unit.get_cargo_space_left() > 20:
                closest_resource_tile, unit_positions = find_closest_resources(unit.pos, player, resource_tiles, unit_positions)
                if closest_resource_tile is not None:
                    move_direction = unit.pos.direction_to(closest_resource_tile.pos)
                    action = unit.move(move_direction)
                    unit_positions.append(unit.pos.translate(move_direction, 1))
                    actions.append(action)
            else:
                closest_city_tile = find_closest_city_tile(unit.pos, player)
                if closest_city_tile is not None:
                    move_direction = unit.pos.direction_to(closest_city_tile.pos)
                    actions.append(unit.move(move_direction))
                    unit_positions.append(unit.pos.translate(move_direction, 1))
    
    for city in player.cities.values():
        for city_tile in city.citytiles:
            if city_tile.can_act():
                if city_can_build_cart_or_worker(player):
                    actions.append(city_tile.build_worker())
                else:
                    actions.append(city_tile.research())

    return actions
# Out:
# Overwriting agent.py

# %%
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)
steps = env.run([agent, "simple_agent"])
env.render(mode="ipython", width=1200, height=800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3356/3312907952.py in <module>
#       1 env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)
# ----> 2 steps = env.run([agent, "simple_agent"])
#       3 env.render(mode="ipython", width=1200, height=800)
#
# NameError: name 'agent' is not defined

# %% [markdown]
# ## Create a submission
# Now we need to create a .tar.gz file with main.py (and agent.py) at the top level. We can then upload this!

# %%
# !tar -czf submission.tar.gz *

# %% [markdown]
# ## Submit
# Now open the /kaggle/working folder and find submission.tar.gz, download that file, navigate to the "MySubmissions" tab in https://www.kaggle.com/c/lux-ai-2021/ and upload your submission! It should play a validation match against itself and once it succeeds it will be automatically matched against other players' submissions. Newer submissions will be prioritized for games over older ones. Your team is limited in the number of succesful submissions per day so we highly recommend testing your bot locally before submitting.

# %% [markdown]
# ## CLI Tool
#
# There's a separate CLI tool that can also be used to run matches. It's recommended for Jupyter Notebook users to stick with just this notebook, and all other users including python users to follow the instructions on https://github.com/Lux-AI-Challenge/Lux-Design-2021
#
# The other benefit however of using the CLI tool is that it generates much smaller, "stateless" replays and also lets you run a mini leaderboard on multiple bots ranked by various ranking algorithms

# %% [markdown]
# ## Additional things to check out
#
# Make sure you check out the Bot API at https://github.com/Lux-AI-Challenge/Lux-Design-2021/tree/master/kits
#
# This documents what you can do using the starter kit files in addition to telling you how to use the annotation debug commands that let you annotate directly on a replay (draw lines, circle things etc.)
#
# You can also run the following below to save a episode to a JSON replay file. These are the same as what is shown on the leaderbaord and you can upload the replay files to the online replay viewer https://2021vis.lux-ai.org/
#
#
# For a local (faster) version of the replay viewer, follow installation instructions here https://github.com/Lux-AI-Challenge/Lux-Viewer-2021

# %%
import json
replay = env.toJSON()
with open("replay.json", "w") as f:
    json.dump(replay, f)

# %% [markdown]
# ## Suggestions / Strategies
#
# There are a lot of places that could be improved with the agent we have in this tutorial notebook. Here are some!
#
# - Using the build city action to build new cities and thus build new units
# - Having cities perform research each turn to unlock new resources
# - Writing collision-free code that lets units move smoothly around and through each other when navigating to targets
# - Mining resources near your opponent's citytiles so they have less easy access to resources
# - Using carts to deliver resources from far away clusters of wood, coal, uranium to a city in need
# - Sending worker units over to the opponent's roads and pillaging them to slow down their agent
# - Optimizing over how much to mine out of forests before letting them regrow so you can build more cities and get sustainable fuel
